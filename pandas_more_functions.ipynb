# %%
import pandas as pd
import numpy as np #importing lib

# %%
data=pd.read_csv("movies.csv") #importing file
data.head(2) # redaing 2 rows of table
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
#
#                         homepage         director             tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow   The park is open.  ...
# 1    http://www.madmaxmovie.com/    George Miller  What a Lovely Day.  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
#
# ...

# %%
data.tail(2) # reading last 2 rows pof table
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
#                director                                       tagline  ...  \
# 10864       Woody Allen                     WOODY ALLEN STRIKES BACK!  ...
# 10865  Harold P. Warren  It's Shocking! It's Beyond Your Imagination!  ...
#
#                                                 overview runtime  \
# 10864  In comic Woody Allen's film debut, he took the...      80
# 10865  A family gets lost on the road and stumbles up...      74
#
# ...

# %%
data.describe() # getting info of table max,min,std,var #descrbe only those have integer values
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
data.describe(include="object") #descibe only object values
# Out:
#           imdb_id original_title        cast             homepage  \
# count       10856          10866       10790                 2936
# unique      10855          10571       10719                 2896
# top     tt0411951         Hamlet  Louis C.K.  http://phantasm.com
# freq            2              4           6                    4
#
#            director                 tagline        keywords  \
# count         10822                    8042            9373
# unique         5067                    7997            8804
# top     Woody Allen  Based on a true story.  woman director
# freq             45                       5             134
#
#                   overview  genres production_companies release_date
# count                10862   10843                 9836        10866
# unique               10847    2039                 7445         5909
# top     No overview found.  Comedy   Paramount Pictures       1/1/09
# ...

# %%
data.describe(include="all") #descirbe all integer + object
# Out:
#                    id    imdb_id    popularity        budget       revenue  \
# count    10866.000000      10856  10866.000000  1.086600e+04  1.086600e+04
# unique            NaN      10855           NaN           NaN           NaN
# top               NaN  tt0411951           NaN           NaN           NaN
# freq              NaN          2           NaN           NaN           NaN
# mean     66064.177434        NaN      0.646441  1.462570e+07  3.982332e+07
# std      92130.136561        NaN      1.000185  3.091321e+07  1.170035e+08
# min          5.000000        NaN      0.000065  0.000000e+00  0.000000e+00
# 25%      10596.250000        NaN      0.207583  0.000000e+00  0.000000e+00
# 50%      20669.000000        NaN      0.383856  0.000000e+00  0.000000e+00
# 75%      75610.000000        NaN      0.713817  1.500000e+07  2.400000e+07
# max     417859.000000        NaN     32.985763  4.250000e+08  2.781506e+09
#
# ...

# %%
data.mean() # getting mean of every feature
# Out:
# id              6.606418e+04
# popularity      6.464410e-01
# budget          1.462570e+07
# revenue         3.982332e+07
# runtime         1.020709e+02
# vote_count      2.173897e+02
# vote_average    5.974922e+00
# release_year    2.001323e+03
# budget_adj      1.755104e+07
# revenue_adj     5.136436e+07
# dtype: float64

# %%
data["budhet$"].mean() #getting mean of only buget feature
# Out:
# 14625701.09414688

# %%
data.median() # egtting median
# Out:
# id              20669.000000
# popularity          0.383856
# budget              0.000000
# revenue             0.000000
# runtime            99.000000
# vote_count         38.000000
# vote_average        6.000000
# release_year     2006.000000
# budget_adj          0.000000
# revenue_adj         0.000000
# dtype: float64

# %%
data["budget"].median() #median of budget colunms
# Out:
# 0.0

# %%
data.mode() # getting mode
# Out:
#          id    imdb_id  popularity  budget  revenue original_title  \
# 0   42194.0  tt0411951    0.011798     0.0      0.0         Hamlet
# 1       NaN        NaN    0.021121     NaN      NaN            NaN
# 2       NaN        NaN    0.028143     NaN      NaN            NaN
# 3       NaN        NaN    0.044913     NaN      NaN            NaN
# 4       NaN        NaN    0.060425     NaN      NaN            NaN
# 5       NaN        NaN    0.065543     NaN      NaN            NaN
# 6       NaN        NaN    0.071830     NaN      NaN            NaN
# 7       NaN        NaN    0.078482     NaN      NaN            NaN
# 8       NaN        NaN    0.083178     NaN      NaN            NaN
# 9       NaN        NaN    0.090552     NaN      NaN            NaN
# 10      NaN        NaN    0.109305     NaN      NaN            NaN
# 11      NaN        NaN    0.111351     NaN      NaN            NaN
# 12      NaN        NaN    0.114027     NaN      NaN            NaN
# ...

# %%
data["budget"].mode()
# Out:
# 0    0
# dtype: int64

# %%
data.std() #getting standard variance
# Out:
# id              9.213014e+04
# popularity      1.000185e+00
# budget          3.091321e+07
# revenue         1.170035e+08
# runtime         3.138141e+01
# vote_count      5.756191e+02
# vote_average    9.351418e-01
# release_year    1.281294e+01
# budget_adj      3.430616e+07
# revenue_adj     1.446325e+08
# dtype: float64

# %%
data.var() # getting variance
# Out:
# id              8.487962e+09
# popularity      1.000370e+00
# budget          9.556268e+14
# revenue         1.368982e+16
# runtime         9.847926e+02
# vote_count      3.313373e+05
# vote_average    8.744902e-01
# release_year    1.641714e+02
# budget_adj      1.176912e+15
# revenue_adj     2.091856e+16
# dtype: float64

# %%
data.rename(columns={"budget":"budhet$"},inplace=True ) # renaming coulmn budget

# %%
data.columns # getting columns names
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budhet$', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
data.max() #getting max
# Out:
# id                     417859
# popularity            32.9858
# budhet$             425000000
# revenue            2781505847
# original_title       í•˜ìš¸ë§
# runtime                   900
# release_date           9/9/97
# vote_count               9767
# vote_average              9.2
# release_year             2015
# budget_adj           4.25e+08
# revenue_adj       2.82712e+09
# dtype: object

# %%
data["budhet$"].max() #getting max of buget coulmn
# Out:
# 425000000

# %%
data.min() # getting minimum
# Out:
# id                       5
# popularity         6.5e-05
# budhet$                  0
# revenue                  0
# original_title    $5 a Day
# runtime                  0
# release_date        1/1/00
# vote_count              10
# vote_average           1.5
# release_year          1960
# budget_adj               0
# revenue_adj              0
# dtype: object

# %%
data["budhet$"].min()
# Out:
# 0

# %%
data["budhet$"].groupby(data["id"]).mean() # grouping budget and id coulnm by their mean
# Out:
# id
# 5           4000000
# 6                 0
# 11         11000000
# 12         94000000
# 13         55000000
# 14         15000000
# 16         12800000
# 17                0
# 18         90000000
# 20                0
# 21                0
# 22        140000000
# 24         30000000
# 25         72000000
# 26          1400000
# 27          1000000
# 28         31500000
# 33         14000000
# 35         75000000
# 38         20000000
# 58        200000000
# 59         32000000
# 62         12000000
# 63         29500000
# 65         41000000
# 66         50000000
# 67                0
# 68         15000000
# 69         28000000
# 70         30000000
#             ...
# 365805            0
# 365806            0
# 366018            0
# 366142            0
# 366929            0
# 367186            0
# 367215            0
# 367326            0
# 367551            0
# 367735            0
# 368256            0
# 369058            0
# 369145            0
# 370687            0
# ...

# %%
data.sort_values(by="id") # sorting id values
# Out:
#            id    imdb_id  popularity    budhet$     revenue  \
# 8088        5  tt0113101    1.234890    4000000     4300000
# 10249       6  tt0107286    0.815631          0    12136938
# 1329       11  tt0076759   12.037933   11000000   775398007
# 4955       12  tt0266543    3.440519   94000000   864625978
# 4179       13  tt0109830    6.715966   55000000   677945399
# 2411       14  tt0169547    3.555720   15000000   356296601
# 8695       16  tt0168629    0.977410   12800000    40031879
# 6869       17  tt0411267    0.546134          0           0
# 5235       18  tt0119116    2.972972   90000000   263920180
# 5131       20  tt0314412    0.282490          0     9726954
# 10861      21  tt0060371    0.080598          0           0
# 4951       22  tt0325980    6.864067  140000000   655011224
# 4952       24  tt0266697    6.174132   30000000   180949000
# 6236       25  tt0418763    1.148377   72000000    96889998
# 7204       26  tt0352994    0.192215    1400000           0
# ...

# %%
data["duplicate"]=data.duplicated() # creating duplicate coulmn and checking any duplicate value returning bool value
data.head(2)
# Out:
#        id    imdb_id  popularity    budhet$     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
#
#                         homepage         director             tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow   The park is open.  ...
# 1    http://www.madmaxmovie.com/    George Miller  What a Lovely Day.  ...
#
#   runtime                                     genres  \
# 0     124  Action|Adventure|Science Fiction|Thriller
# 1     120  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# ...

# %%
data.loc[data["revenue"].idmax()] # fucntion to get whole row value whichgg have max value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-610a908d7aee> in <module>
# ----> 1 data.loc[data["revenue"].idmax()]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'idmax'

# %%
data["budhet$"].unique() #getting unique values of budget column
# Out:
# array([150000000, 110000000, 200000000, 190000000, 135000000, 155000000,
#        108000000,  74000000, 175000000, 245000000, 176000003,  15000000,
#         88000000, 280000000,  44000000,  48000000, 130000000,  95000000,
#        160000000,  30000000,  40000000,  28000000,  68000000,  81000000,
#         20000000,  61000000,         0,  49000000,  29000000,  58000000,
#          6000000,  50000000,  11000000,  90000000,  75000000,  25000000,
#         10000000,  12000000,   4000000,  11800000,  35000000,  55000000,
#         60000000, 105000000,  26000000,  70000000, 120000001,   3500000,
#         65000000,  50100000, 100000000,  13000000,  99000000,   2500000,
#         34000000,  80000000,  17000000,  31000000,   5000000,  64000000,
#         11930000,   8500000,  23000000,  53000000,   8900000,    700000,
#         14800000,  19500000,   1000000,   8000000,   1800000,   2000000,
#         18000000,    630019,  14000000,  37000000,   7000000,   3000000,
# ...

# %%
data[:2] #coulumns:row
# Out:
#        id    imdb_id  popularity    budhet$     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
#
#                         homepage         director             tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow   The park is open.  ...
# 1    http://www.madmaxmovie.com/    George Miller  What a Lovely Day.  ...
#
#   runtime                                     genres  \
# 0     124  Action|Adventure|Science Fiction|Thriller
# 1     120  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# ...

# %%
data[2:5]
# Out:
#        id    imdb_id  popularity    budhet$     revenue  \
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline  ... runtime  \
# 2     One Choice Can Destroy You  ...     119
# ...
